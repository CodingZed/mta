# %% [markdown]
# ## Import dataset

# %%
import pandas as pd
import numpy as np

# %%
chunksize=10**5
for chunk in pd.read_csv('DCD_April.csv',chunksize=chunksize):
    print (chunk)
# Out:
#                                            Unique Row ID       CVO SID  \
# 0      5W9DNMBQDD9D_1491602098.559270_1955401_-256266...  5W9DNMBQDD9D
# 1       7XPU6KNGJ5SQ_1492811571.793190_1765394_1765394_0  7XPU6KNGJ5SQ
# 2      7XPU6KNGJ5SQ_1492014392.807390_1765394_7977328...  7XPU6KNGJ5SQ
# 3      7XPU6KNGJ5SQ_1492811456.295440_1765394_-472462...  7XPU6KNGJ5SQ
# 4       BC74CSTCWWQ2_1492799280.000000_2253029_2253029_0  BC74CSTCWWQ2
# 5       4KJCHAH95WAX_1491024060.000000_2253032_2253032_0  4KJCHAH95WAX
# 6       E9M3X7NR8V6H_1493589892.345290_1765396_1765396_0  E9M3X7NR8V6H
# 7      E9M3X7NR8V6H_1493589862.773500_1765396_5276178...  E9M3X7NR8V6H
# 8      4TVWFRWZMGDT_1492625520.676810_1765397_6903969...  4TVWFRWZMGDT
# 9       CGSHKNUKCDAT_1492627740.000000_2913752_2913752_0  CGSHKNUKCDAT
# 10     CGSHKNUKCDAT_1482338384.529850_2913752_-787408...  CGSHKNUKCDAT
# 11     CGSHKNUKCDAT_1482468103.578670_2913752_-303670...  CGSHKNUKCDAT
# ...

# %%
chunk.columns
# Out:
# Index(['Unique Row ID', 'CVO SID', 'Event Site ID', 'Touchpoint Site ID',
#        'Event Site Name', 'Touchpoint Site Name', 'Event Type', 'Event ID',
#        'Event Date/Timestamp', 'Touchpoint Date/Timestamp',
#        'Total Event Value', 'Touchpoint Revenue', 'Conversion',
#        'Touchpoint Type', 'First Touch Date/Timestamp',
#        'Last Touch Date/Timestamp', 'Source 1', 'Source 2', 'Source 3',
#        'Touchpoints in Path', 'Attribution Sequence', 'Path Position'],
#       dtype='object')

# %%
df1=pd.read_csv('DCD_April.csv')
# Out:
# C:\Users\zfang\AppData\Local\Continuum\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df1.dtypes
# Out:
# Unique Row ID                  object
# CVO SID                        object
# Event Site ID                   int64
# Touchpoint Site ID              int64
# Event Site Name                object
# Touchpoint Site Name           object
# Event Type                     object
# Event ID                       object
# Event Date/Timestamp           object
# Touchpoint Date/Timestamp      object
# Total Event Value             float64
# Touchpoint Revenue            float64
# Conversion                    float64
# Touchpoint Type                object
# First Touch Date/Timestamp     object
# Last Touch Date/Timestamp      object
# Source 1                       object
# Source 2                       object
# Source 3                       object
# Touchpoints in Path             int64
# Attribution Sequence            int64
# Path Position                  object
# dtype: object

# %%
df1['Event Date/Timestamp']=pd.to_datetime(df1['Event Date/Timestamp'])
df1['Touchpoint Date/Timestamp']=pd.to_datetime(df1['Touchpoint Date/Timestamp'])

# %%
df1.dtypes
# Out:
# Unique Row ID                         object
# CVO SID                               object
# Event Site ID                          int64
# Touchpoint Site ID                     int64
# Event Site Name                       object
# Touchpoint Site Name                  object
# Event Type                            object
# Event ID                              object
# Event Date/Timestamp          datetime64[ns]
# Touchpoint Date/Timestamp     datetime64[ns]
# Total Event Value                    float64
# Touchpoint Revenue                   float64
# Conversion                           float64
# Touchpoint Type                       object
# First Touch Date/Timestamp            object
# Last Touch Date/Timestamp             object
# Source 1                              object
# Source 2                              object
# Source 3                              object
# Touchpoints in Path                    int64
# Attribution Sequence                   int64
# ...

# %%
del df1['First Touch Date/Timestamp']
del df1['Last Touch Date/Timestamp']
